# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:/Users/welcome/Downloads/adult.csv", na_values = '?')

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18        NaN  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                NaN    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
df.isnull().sum()/len(df)
# Out:
# age                0.000000
# workclass          0.057307
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         0.057512
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     0.017546
# income             0.000000
# dtype: float64

# %%
df1 = df.copy()

# %%
df2 = df1.dropna()

# %%
len(df2)
# Out:
# 45222

# %%
len(df1)
# Out:
# 48842

# %%
# By dropping na values, we are missing 7% of the data which is accepted.
(len(df1)-len(df2))/len(df1)*100
# Out:
# 7.411653904426519

# %%
df2.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
numeric = []
for i in df2.columns:
    if (df[i].dtype != 'O'):
        numeric.append(i)

# %%
numeric
# Out:
# ['age',
#  'fnlwgt',
#  'educational-num',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week']

# %%
categorical = []
for i in df2.columns:
    if (df[i].dtype == 'O'):
        categorical.append(i)

categorical
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'gender',
#  'native-country',
#  'income']

# %% [markdown]
# # Univariate Analysis

# %%
sns.distplot(df2['age'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# - Most of the people are aged between 20 to 45
# - Distribution is rightly skewed

# %%
sns.distplot(df2['fnlwgt'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# - Highest value of the fnlwgt is 2 lakhs
# - Most people are having fnlwgt between 1 to 3 lakhs

# %%
sns.distplot(df2['educational-num'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# - The count of educational-num is high at approximately at 8.5

# %%
sns.boxplot(df2['educational-num'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - Box plot shows there are outliers in educational-num variable below value 2

# %%
sns.violinplot(df2["educational-num"])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df2['age'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - Data shows people with age more than 75 are outliers.

# %%
sns.boxplot(df2['fnlwgt'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - Data shows there are outliers for fnlwgt variable after value 4 lakhs.

# %%
plt.figure(figsize=(15,5))
sns.boxplot(df2['hours-per-week'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - Data shows that people who worked more than 55 hours-per-week (approx) and less than 35 hours-per-week (approx) are outliers.

# %%
IQR=df2['hours-per-week'].quantile(0.75)-df2['hours-per-week'].quantile(0.25)
lower_bridge=df2['hours-per-week'].quantile(0.25)-(IQR*1.5)
upper_bridge=df2['hours-per-week'].quantile(0.75)+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# 32.5
# 52.5
# (None, None)

# %%
df2.loc[df2['hours-per-week']<=32.5 ,'hours-per-week']=32.5
df2.loc[df2['hours-per-week']>=52.5,'hours-per-week']=52.5

# %%
plt.figure(figsize=(15,5))
sns.countplot(df2['workclass'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - Data clearly shows that most of the people are from Private workclass which is approximately 350000
# - Clearly Private workclass dominates all other workclass

# %%
plt.figure(figsize=(15,5))
sns.countplot(df2['education'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - Data shows that most of the people are from HS-grad followed by Some-college, Bachelors and so on.

# %%
plt.figure(figsize=(15,5))
sns.countplot(df2['marital-status'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - We can observe most of the people are Married-civ-spouse followed by Never-married, Divorced and so on.

# %%
plt.figure(figsize=(15,5))
sns.countplot(df2['occupation'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - We can observe the highest number of occupation is Prof-specialty and Craft-repair
# - Least number of occupation from this data is Armed-Forces

# %%
plt.figure(figsize=(15,5))
sns.countplot(df2['gender'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - There is a huge difference between the count of male and female

# %%
plt.figure(figsize=(15,5))
sns.countplot(df2['race'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - Data shows people who belong to white race are more in number followed by black

# %%
plt.figure(figsize=(15,5))
sns.countplot(df2['income'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - We can observe most of the people are earning less than 50 thousand
# - Only 12 thousand people (approximately) are earning more than 50 thousand

# %% [markdown]
# ## Outlier Treatment

# %%
IQR=df2['hours-per-week'].quantile(0.75)-df2['hours-per-week'].quantile(0.25)
lower_bridge=df2['hours-per-week'].quantile(0.25)-(IQR*1.5)
upper_bridge=df2['hours-per-week'].quantile(0.75)+(IQR*1.5)
print(lower_bridge), print(upper_bridge)
# Out:
# 32.5
# 52.5
# (None, None)

# %%
df2.loc[df1['hours-per-week']<=32.5 ,'hours-per-week']=32.5
df2.loc[df1['hours-per-week']>=52.5,'hours-per-week']=52.5

# %% [markdown]
# - Replacing the outliers with the extreme values

# %% [markdown]
# # Bivariate Analysis

# %%
sns.scatterplot(df2['age'],df2['hours-per-week'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
corr = df2.corr()

# %%
plt.figure(figsize=(15,5))
sns.heatmap(corr)

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(df2['capital-gain'],df2['hours-per-week'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,5))
sns.relplot(df2['age'],df2['fnlwgt'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - we can observe the people with highest fnlwgt is below age 45.
# - Most of the people are having fnlwgt less than 6 lakhs.

# %%
sns.scatterplot(df2['hours-per-week'], df2['age'],hue = df2['gender'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - we can observe most number of male are working long hours at different ages.

# %%
plt.figure(figsize=(15,5))
sns.boxplot(df2['age'],df2['gender'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - The age of male are slightly more than the female

# %%
plt.figure(figsize=(15,5))
sns.boxplot(df2['age'],df2['occupation'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - We can observe the highest age of the people are from Priv-house-serv followed by Farming-fishing.
# - The age of the people whose occupation is Armed-Forces is less than 40

# %%
plt.figure(figsize=(15,5))
sns.boxplot(df2['age'],df2['income'])
# Out:
# C:\Users\welcome\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - We can observe the age of the people who are earning more than 50 thousand are more than the age of the people who are earning less than 50 thousand

# %%
df2.dtypes
# Out:
# age                  int64
# workclass           object
# fnlwgt               int64
# education           object
# educational-num      int64
# marital-status      object
# occupation          object
# relationship        object
# race                object
# gender              object
# capital-gain         int64
# capital-loss         int64
# hours-per-week     float64
# native-country      object
# income              object
# dtype: object
